# %%
import os
import requests
import json
import re
import time
import glob
import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from os.path import join
from slugify import slugify
from bs4 import BeautifulSoup
from bs4.element import NavigableString
from urllib.parse import urlparse, parse_qs

base_dir = "任天堂株式会社"
if not os.path.exists(base_dir):
    os.makedirs(base_dir)

# %%
def fn(d, s):
    fl = "item-%d-%d.json" % (s+1, s + rows)
    return join(d,fl)

# %%
# Nintendo EU
start = 0
rows = 200
parameters = {
    'q':'*',
    'fq':'',
    'sort': 'date_from desc',
    'start': start,
    'rows': rows,
    'wt': 'json'
}
languages = ['es', 'en', 'it', 'fr', 'de']
original_url = "https://search.nintendo-europe.com/%s/select"

# %%
for language in languages:
    print("Language", language)
    url = original_url % language
    folder = join(base_dir, language)
    if not os.path.exists(folder):
        os.makedirs(folder)
        
    start = 0
    rows = 300
    parameters['rows'] = rows
    
    request = requests.get(url, parameters)
    data = json.loads(request.text)
    
    total = int(data["response"]["numFound"])
    
    with open(fn(folder, start), "w") as f:
        json.dump(data, f)
    
    while start <= total:
        if start % 500 == 0:
            print("Item", start)
        start = start + rows
        parameters['start'] = start
        
        
        request = requests.get(url, parameters)
        data = json.loads(request.text)
        
        with open(fn(folder, start), "w") as f:
            json.dump(data, f)
# Out:
# Language es
# Item 0
# Item 1500
# Item 3000
# Item 4500
# Item 6000
# Item 7500
# Item 9000
# Item 10500
# Language en
# Item 0
# Item 1500
# Item 3000
# Item 4500
# Item 6000
# Item 7500
# Item 9000
# Item 10500
# Language it
# Item 0
# Item 1500
# Item 3000
# Item 4500
# Item 6000
# Item 7500
# Item 9000
# Item 10500
# Language fr
# Item 0
# Item 1500
# Item 3000
# Item 4500
# Item 6000
# Item 7500
# Item 9000
# Item 10500
# Language de
# Item 0
# Item 1500
# Item 3000
# Item 4500
# Item 6000
# Item 7500
# Item 9000
# Item 10500

# %%
# Nintendo US
start = 0
rows = 300
parameters = {
    'limit': rows,
    'offset': start,
    'sort': 'featured',
    'direction':'des'
}
original_url = "https://www.nintendo.com/json/content/get/filter/game"

# %%
language = "us"
print("Language", language)
url = original_url
folder = join(base_dir, language)
if not os.path.exists(folder):
    os.makedirs(folder)

start = 0
rows = 300
parameters['limit'] = rows

request = requests.get(url, parameters)
data = json.loads(request.text)

total = int(data["filter"]["total"])

with open(fn(folder, start), "w") as f:
    json.dump(data, f)

while start <= total:
    if start % 500 == 0:
        print("Item", start)
    start = start + rows
    parameters['offset'] = start


    request = requests.get(url, parameters)
    data = json.loads(request.text)

    with open(fn(folder, start), "w") as f:
        json.dump(data, f)
# Out:
# Language us
# {"filter":{"free_start":{"total":29},"categories":{"category":[{"name":"action_adventure","total":2927},{"name":"application","total":24},{"name":"first_person","total":155},{"name":"party","total":208},{"name":"role_playing","total":496},{"name":"music_fitness","total":204},{"name":"education","total":134},{"name":"puzzle_strategy","total":608},{"name":"simulation","total":591},{"name":"sports_racing","total":714}],"total":7523},"prices":{"price":[{"name":"4.99","total":917},{"name":"9.99","total":830},{"name":"19.99","total":410},{"name":"39.99","total":311},{"name":"40_plus","total":111}],"total":2579},"availabilities":{"availability":[{"name":"now","total":6253},{"name":"new","total":36},{"name":"soon","total":60},{"name":"prepurchase","total":57}],"total":6406},"sale":{"total":91},"number_of_players":{"number_of_players":[{"name":1,"total":6147},{"name":2,"total":2666},{"name":3,"total":1294},{"name":4,"total":1264}],"total":11371},"how_to_play":{"how_to_play":[{"name":"amiibo","total":88},{"name":"off_tv","total":780},{"name":"online","total":42}],"total":910},"franchises":{"franchise":[{"name":"animal_crossing","total":17},{"name":"mario","total":201},{"name":"zelda","total":56},{"name":"donkey_kong","total":66},{"name":"metroid","total":28},{"name":"pokemon","total":83},{"name":"mii","total":90},{"name":"kirby","total":51}],"total":592},"dlc":{"total":147},"publishers":{"publisher":[{"name":"nintendo","total":827},{"name":"others","total":5457}],"total":6284},"vcs":{"vc":[{"name":"nes","total":246},{"name":"snes","total":147},{"name":"gb","total":48},{"name":"gbc","total":29},{"name":"n64","total":39},{"name":"gba","total":73},{"name":"ds","total":30},{"name":"other","total":251}],"total":863},"esrbs":{"esrb":[{"name":"everyone","total":4011},{"name":"early_childhood","total":15},{"name":"everyone_10_plus","total":1257},{"name":"teen","total":829},{"name":"mature","total":129},{"name":"pending","total":23}],"total":6264},"shop":{"shop":[{"name":"retail","total":775},{"name":"ncom","total":3060}],"total":3835},"demo":{"total":294},"total":6313,"systems":{"system":[{"name":"ds","total":1837},{"name":"3ds","total":1229},{"name":"wii","total":1755},{"name":"wii_u","total":1030},{"name":"ios","total":6},{"name":"android","total":6},{"name":"ios_android","total":0},{"name":"switch","total":449}],"total":6312}},"games":{"offset":0,"game":[{"categories":{"category":["Action","Platformer"]},"buyitnow":"false","slug":"yoshi-for-nintendo-switch","release_date":"Dec 31, 2019","digitaldownload":"false","free_to_start":"false","title":"Yoshi for Nintendo Switch (Working Title)","system":"Nintendo Switch","id":"xL2fky2sE-ipFtbqsX25CwKX6thEyZQl","number_of_players":"2 players simultaneous","release_date_display":"2018","front_box_art":"https://media.nintendo.com/nintendo/bin/QtQzkbMvMc5UL3L6KPKeYn9IlRG5oAYV/BONpzcCQDis9Gxf-P61eH1YMKwnBM4B5.png","game_code":"HAC","buyonline":"true"},{"categories":{"category":["Puzzles","Action"]},"buyitnow":"false","slug":"sushi-striker-the-way-of-sushido-3ds","release_date":"Dec 31, 2018","digitaldownload":"false","free_to_start":"false","title":"Sushi Striker: The Way of Sushido","system":"Nintendo 3DS","id":"E5ur-qFH8lEqA9gm2plVSYnx-ppz7KU6","number_of_players":"To be determined","release_date_display":"2018","front_box_art":"https://media.nintendo.com/nintendo/bin/RpDDNXh8SUMOgsfn9WFU84-nY4gQlMwf/OANAq8GGi02SGI6nzJQxss_7_Wa395rg.png","game_code":"CTR","buyonline":"true"},{"categories":{"category":["Action","Adventure"]},"buyitnow":"true","slug":"hyrule-warriors-switch","release_date":"May 31, 2018","digitaldownload":"true","free_to_start":"false","title":"Hyrule Warriors: Definitive Edition","system":"Nintendo Switch","id":"JgKD3-ld9uAIhni6b7bT4xMZn7rtmGd6","number_of_players":"To be determined","release_date_display":"Spring 2018","front_box_art":"https://media.nintendo.com/nintendo/bin/QLEtCHeHmJX_X-OhyKsDCgxu-vr6ueh2/CgUxF9Jbtyxp9INtLdWiVgiWbudmCVD9.png","game_code":"HACNAKUTB","buyonline":"true ...
# Item 0
# Item 1500
# Item 3000
# Item 4500
# Item 6000
